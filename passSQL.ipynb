# %% [markdown]
# <a href="https://colab.research.google.com/github/giovannasoliveira2021/passSQL-test/blob/main/passSQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# vamos colocar uma extensão no colab
# %load_ext NOME_DA_EXTENSAO
# <<<< carregamos nossa plataforma
# %load_ext sql

# tenho comando de uma extensão
# criar um banco de dados
# %sql sqlite:///nome_do_banco_de_dados.db
# %sql sqlite:///playlist.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# comandos basicos de um banco de dados
# %%sql
create table minhaplaylist(
  id_minhaplaylist integer auto_increment primary key,
  musica text not null,
  artista text not null
);
# Out:
#  * sqlite:///playlist.db
# Done.
# []

# %%
print("----- MINHA PLAYLIST -----")

while True:
  musica = input("informe o nome da música")
  artista = input("informe o artista")

  # vamos chamar nosso paas para salvar as informações
  # insert into nome_da_tabela (campos) values (valores)
  # %sql insert into minhaplaylist (musica, artista) values (:musica, :artista)
  print("informações adicionadas para o banco de dados")

  op = input("quer adicionar nova musica? s/n")
  if op.lower()=="n":
    break
# Out:
# ----- MINHA PLAYLIST -----
# informe o nome da músicaEstrelas Part II
# informe o artistaCartel Mcs
#  * sqlite:///playlist.db
# 1 rows affected.
# informações adicionadas para o banco de dados
# quer adicionar nova musica? s/ns
# informe o nome da músicaDoce Veneno
# informe o artistaCosta Gold
#  * sqlite:///playlist.db
# 1 rows affected.
# informações adicionadas para o banco de dados
# quer adicionar nova musica? s/ns
# informe o nome da músicaFlor de Tangerina
# informe o artistaAlceu Valença
#  * sqlite:///playlist.db
# 1 rows affected.
# informações adicionadas para o banco de dados
# quer adicionar nova musica? s/nn
